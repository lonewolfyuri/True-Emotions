# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir(r'/content/drive/Shared drives/Emotion Classification Through Deep Learning Drive/fer2013/fer2013')
from fer2013_loader import fer2013
import matplotlib.pyplot as plt

# %%
dataset = fer2013()
#dataset.shuffle(seed=10)

# %%
nrows=4
ncols=5
figsize = (25,15)
fig, ax = plt.subplots(ncols=ncols,nrows=nrows,figsize = figsize)
print(ax.shape)
prevNum = 0
for ii in range(nrows):
    for jj in range(ncols):
        dataset.plot_image(ii*(ncols)+jj,ax=ax[ii,jj],cmap='gray')
# Out:
# (4, 5)

# %%
ax.shape
# Out:
# (3, 4)
